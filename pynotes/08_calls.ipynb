# %%
import pandas as pd
import numpy as np

import plotly.offline as py
import plotly.express as px

import plotly.graph_objs as go
import plotly.figure_factory as ff
import cufflinks as cf
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
calls = pd.read_csv('data/calls_for_service.csv', warn_bad_lines=True)
calls.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1  19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2  19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3  19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4  19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
#
#          CVLEGEND  CVDOW                InDbDate  \
# 0         LARCENY      1  09/10/2020 07:00:11 AM
# 1  DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2         ASSAULT      3  09/10/2020 07:00:10 AM
# 3       VANDALISM      0  09/10/2020 07:00:11 AM
# 4         ASSAULT      6  09/10/2020 07:00:08 AM
#
#                                       Block_Location  \
# 0                         SHATTUCK AVE\nBerkeley, CA
# 1           FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2  2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                          VIRGINIA ST\nBerkeley, CA
# 4          UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
#
#                        BLKADDR      City State
# 0                 SHATTUCK AVE  Berkeley    CA
# 1   FRONTAGE STREET &GILMAN ST  Berkeley    CA
# 2               2200 MILVIA ST  Berkeley    CA
# 3                  VIRGINIA ST  Berkeley    CA
# 4  UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA

# %% [markdown]
# Decoding day of the week using `merge`

# %%
dow = pd.Series(["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"], name="Day")
df_dow = pd.DataFrame(dow)

calls = pd.merge(calls.drop(columns="Day", errors="ignore"), 
         df_dow, left_on='CVDOW', right_index=True).sort_index()
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1     19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2     19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3     19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4     19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
# ...        ...                       ...                     ...     ...
# 5222  19092686             BURGLARY AUTO  12/02/2019 12:00:00 AM   08:30
# 5223  19043965  THEFT MISD. (UNDER $950)  08/05/2019 12:00:00 AM   23:30
# 5224  19052923             BURGLARY AUTO  09/19/2019 12:00:00 AM   13:30
# 5225  19049410               DISTURBANCE  08/05/2019 12:00:00 AM   10:00
# 5226  19092182             BURGLARY AUTO  10/10/2019 12:00:00 AM   09:55
#
#                 CVLEGEND  CVDOW                InDbDate  \
# 0                LARCENY      1  09/10/2020 07:00:11 AM
# 1         DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2                ASSAULT      3  09/10/2020 07:00:10 AM
# 3              VANDALISM      0  09/10/2020 07:00:11 AM
# 4                ASSAULT      6  09/10/2020 07:00:08 AM
# ...                  ...    ...                     ...
# 5222  BURGLARY - VEHICLE      1  09/10/2020 07:00:11 AM
# 5223             LARCENY      1  09/10/2020 07:00:08 AM
# 5224  BURGLARY - VEHICLE      4  09/10/2020 07:00:09 AM
# 5225  DISORDERLY CONDUCT      1  09/10/2020 07:00:09 AM
# 5226  BURGLARY - VEHICLE      4  09/10/2020 07:00:10 AM
#
#                                          Block_Location  \
# 0                            SHATTUCK AVE\nBerkeley, CA
# 1              FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2     2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                             VIRGINIA ST\nBerkeley, CA
# 4             UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
# ...                                                 ...
# 5222  1000 GILMAN ST\nBerkeley, CA\n(37.88014, -122....
# 5223  2300 WARD ST\nBerkeley, CA\n(37.860105, -122.2...
# 5224  1500 SHATTUCK AV\nBerkeley, CA\n(37.880227, -1...
# 5225  2900 REGENT ST\nBerkeley, CA\n(37.857787, -122...
# 5226  1500 SHATTUCK AV\nBerkeley, CA\n(37.880227, -1...
#
#                           BLKADDR      City State        Day
# 0                    SHATTUCK AVE  Berkeley    CA     Monday
# 1      FRONTAGE STREET &GILMAN ST  Berkeley    CA     Sunday
# 2                  2200 MILVIA ST  Berkeley    CA  Wednesday
# 3                     VIRGINIA ST  Berkeley    CA     Sunday
# 4     UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA   Saturday
# ...                           ...       ...   ...        ...
# 5222               1000 GILMAN ST  Berkeley    CA     Monday
# 5223                 2300 WARD ST  Berkeley    CA     Monday
# 5224             1500 SHATTUCK AV  Berkeley    CA   Thursday
# 5225               2900 REGENT ST  Berkeley    CA     Monday
# 5226             1500 SHATTUCK AV  Berkeley    CA   Thursday
#
# [5227 rows x 12 columns]

# %% [markdown]
# Extract latitude and longitude by regex.

# %%
calls_lat_lon = (
    calls['Block_Location'].str.replace("\n", "\t") 
    .str.extract(".*\((?P<Lat>\d*\.\d*)\, (?P<Lon>-?\d*\.\d*)\)", expand=True)
)
calls_lat_lon.head(10)
# Out:
#          Lat          Lon
# 0        NaN          NaN
# 1        NaN          NaN
# 2  37.868574  -122.270415
# 3        NaN          NaN
# 4        NaN          NaN
# 5        NaN          NaN
# 6        NaN          NaN
# 7        NaN          NaN
# 8        NaN          NaN
# 9  37.871883  -122.301255

# %% [markdown]
# Calculate the fraction of null values in latitude and longitude.

# %%
(~calls_lat_lon.isnull()).mean()
# Out:
# Lat    0.963076
# Lon    0.963076
# dtype: float64

# %%
calls.drop(["Lat", "Lon"], axis=1, inplace=True, errors="ignore")
calls.merge(calls_lat_lon, left_index=True, right_index=True)
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1     19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2     19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3     19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4     19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
# ...        ...                       ...                     ...     ...
# 5222  19092686             BURGLARY AUTO  12/02/2019 12:00:00 AM   08:30
# 5223  19043965  THEFT MISD. (UNDER $950)  08/05/2019 12:00:00 AM   23:30
# 5224  19052923             BURGLARY AUTO  09/19/2019 12:00:00 AM   13:30
# 5225  19049410               DISTURBANCE  08/05/2019 12:00:00 AM   10:00
# 5226  19092182             BURGLARY AUTO  10/10/2019 12:00:00 AM   09:55
#
#                 CVLEGEND  CVDOW                InDbDate  \
# 0                LARCENY      1  09/10/2020 07:00:11 AM
# 1         DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2                ASSAULT      3  09/10/2020 07:00:10 AM
# 3              VANDALISM      0  09/10/2020 07:00:11 AM
# 4                ASSAULT      6  09/10/2020 07:00:08 AM
# ...                  ...    ...                     ...
# 5222  BURGLARY - VEHICLE      1  09/10/2020 07:00:11 AM
# 5223             LARCENY      1  09/10/2020 07:00:08 AM
# 5224  BURGLARY - VEHICLE      4  09/10/2020 07:00:09 AM
# 5225  DISORDERLY CONDUCT      1  09/10/2020 07:00:09 AM
# 5226  BURGLARY - VEHICLE      4  09/10/2020 07:00:10 AM
#
#                                          Block_Location  \
# 0                            SHATTUCK AVE\nBerkeley, CA
# 1              FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2     2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                             VIRGINIA ST\nBerkeley, CA
# 4             UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
# ...                                                 ...
# 5222  1000 GILMAN ST\nBerkeley, CA\n(37.88014, -122....
# 5223  2300 WARD ST\nBerkeley, CA\n(37.860105, -122.2...
# 5224  1500 SHATTUCK AV\nBerkeley, CA\n(37.880227, -1...
# 5225  2900 REGENT ST\nBerkeley, CA\n(37.857787, -122...
# 5226  1500 SHATTUCK AV\nBerkeley, CA\n(37.880227, -1...
#
#                           BLKADDR      City State        Day        Lat  \
# 0                    SHATTUCK AVE  Berkeley    CA     Monday        NaN
# 1      FRONTAGE STREET &GILMAN ST  Berkeley    CA     Sunday        NaN
# 2                  2200 MILVIA ST  Berkeley    CA  Wednesday  37.868574
# 3                     VIRGINIA ST  Berkeley    CA     Sunday        NaN
# 4     UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA   Saturday        NaN
# ...                           ...       ...   ...        ...        ...
# 5222               1000 GILMAN ST  Berkeley    CA     Monday   37.88014
# 5223                 2300 WARD ST  Berkeley    CA     Monday  37.860105
# 5224             1500 SHATTUCK AV  Berkeley    CA   Thursday  37.880227
# 5225               2900 REGENT ST  Berkeley    CA     Monday  37.857787
# 5226             1500 SHATTUCK AV  Berkeley    CA   Thursday  37.880227
#
#               Lon
# 0             NaN
# 1             NaN
# 2     -122.270415
# 3             NaN
# 4             NaN
# ...           ...
# 5222  -122.297498
# 5223  -122.261901
# 5224   -122.26936
# 5225  -122.257013
# 5226   -122.26936
#
# [5227 rows x 14 columns]

# %% [markdown]
# Translate date time

# %%
calls["EVENTDT"][0]
# Out:
# '12/09/2019 12:00:00 AM'

# %%
dates = pd.to_datetime(calls["EVENTDT"])
dates[0]
# Out:
# Timestamp('2019-12-09 00:00:00')

# %%
# Verify the translations
pd.DataFrame(dict(transformed=dates, original=calls["EVENTDT"])).head()
# Out:
#   transformed                original
# 0  2019-12-09  12/09/2019 12:00:00 AM
# 1  2019-08-18  08/18/2019 12:00:00 AM
# 2  2019-10-23  10/23/2019 12:00:00 AM
# 3  2019-12-01  12/01/2019 12:00:00 AM
# 4  2019-08-10  08/10/2019 12:00:00 AM

# %%
# extract time field
times = pd.to_datetime(calls["EVENTTM"]).dt.time
times.head()
# Out:
# 0    13:00:00
# 1    17:20:00
# 2    10:45:00
# 3    18:40:00
# 4    22:51:00
# Name: EVENTTM, dtype: object

# %% [markdown]
# Use built-in python datetime combine function to combine the correct date and correct time field

# %%
from datetime import datetime
timestamps = pd.concat([dates, times], axis=1).apply(
    lambda r: datetime.combine(r['EVENTDT'], r['EVENTTM']), axis=1)
timestamps.head()
# Out:
# 0   2019-12-09 13:00:00
# 1   2019-08-18 17:20:00
# 2   2019-10-23 10:45:00
# 3   2019-12-01 18:40:00
# 4   2019-08-10 22:51:00
# dtype: datetime64[ns]

# %%
calls['timestamp'] = timestamps
calls.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1  19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2  19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3  19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4  19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
#
#          CVLEGEND  CVDOW                InDbDate  \
# 0         LARCENY      1  09/10/2020 07:00:11 AM
# 1  DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2         ASSAULT      3  09/10/2020 07:00:10 AM
# 3       VANDALISM      0  09/10/2020 07:00:11 AM
# 4         ASSAULT      6  09/10/2020 07:00:08 AM
#
#                                       Block_Location  \
# 0                         SHATTUCK AVE\nBerkeley, CA
# 1           FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2  2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                          VIRGINIA ST\nBerkeley, CA
# 4          UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
#
#                        BLKADDR      City State        Day           timestamp
# 0                 SHATTUCK AVE  Berkeley    CA     Monday 2019-12-09 13:00:00
# 1   FRONTAGE STREET &GILMAN ST  Berkeley    CA     Sunday 2019-08-18 17:20:00
# 2               2200 MILVIA ST  Berkeley    CA  Wednesday 2019-10-23 10:45:00
# 3                  VIRGINIA ST  Berkeley    CA     Sunday 2019-12-01 18:40:00
# 4  UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA   Saturday 2019-08-10 22:51:00

# %% [markdown]
# Time range

# %%
calls['timestamp'].min()
calls['timestamp'].max()
# Out:
# Timestamp('2019-12-20 01:30:00')

# %% [markdown]
# Visualizations for datetime

# %%
dow = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
calls.groupby('Day')['CASENO'].count()[dow].iplot(kind='bar', yTitle='Count')
# Out:
# <div>                            <div id="d8e28f12-f748-494b-aa4b-a6134c050af7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("d8e28f12-f748-494b-aa4b-a6134c050af7")) {                    Plotly.newPlot(                        "d8e28f12-f748-494b-aa4b-a6134c050af7",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"CASENO","orientation":"v","text":"","x":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"y":[660,788,730,751,771,778,749],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"ma ...

# %%
calls['hour_of_day'] = (calls['timestamp'].dt.hour * 60 + calls['timestamp'].dt.minute ) / 60.

py.iplot(ff.create_distplot([calls['hour_of_day']],group_labels=["Hour"],bin_size=1, show_rug=False))
# Out:
# <div>                            <div id="7dba3325-3561-4330-a3ed-bf92ac6fbc56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dba3325-3561-4330-a3ed-bf92ac6fbc56")) {                    Plotly.newPlot(                        "7dba3325-3561-4330-a3ed-bf92ac6fbc56",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Hour","marker":{"color":"rgb(31, 119, 180)"},"name":"Hour","opacity":0.7,"x":[13.0,17.333333333333332,10.75,18.666666666666668,22.85,12.0,18.416666666666668,22.0,20.0,14.083333333333334,0.0,11.5,20.0,16.5,21.5,7.333333333333333,13.666666666666666,17.0,13.0,23.166666666666668,22.9,6.0,14.5,7.866666666666666,9.416666666666666,0.0,15.0,13.5,10.5,16.583333333333332,21.166666666666668,11.0,15.033333333333333,6.0,22.0,17.0,11.75,18.166666666666668,17.083333333333332,3.0833333333333335,18.166666666666668,13.683333333333334,12.0,13.883333333333333,8.466666666666667,1.6166666666666667,12.883333333333333,20.0,15.0,21.0,12.066666666666666,0.0,20.0,16.0,22.366666666666667,5.5,13.05,21.5,12.05,21.0,23.783333333333335,12.633333333333333,2.4,14.65,6.333333333333333,18.25,13.45,8.916666666666666,23.633333333333333,22.333333333333332,20.666666666666668,9.0,14.333333333333334,16.0,22.0,13.016666666666667,20.0,12.0,9.483333333333333,17.866666666666667,22.0,17.0,2.966666666666667,22.5,16.833333333333332,0.0,13.0,21.283333333333335,19.066666666666666,18.25,15.583333333333334,14.316666666666666,20.5,3.0,22.0,10.033333333333333,17.75,18.0,15.0,19.0,12.666666666666666,12.5,12.833333333333334,18.5,17.083333333333332,22.0,20.35,16.5,17.583333333333332,19.5,9.0,16.1,1.0,7.2,18.3,23.0,12.0,11.666666666666666,20.083333333333332,11.0,13.033333333333333,21.0,18.5,19.0,11.133333333333333,16.5,0.016666666666666666,21.0,22.416666666666668,4.0,0.0,22.0,20.183333333333334,15.0,22.5,0.25,23.35,19.0,12.25,20.75,18.25,11.0,14.666666666666666,18.916666666666668,15.0,12.916666666666666,22.0,19.8,14.716666666666667,9.0,4.
# %%
calls['OFFENSE'].value_counts().iplot(kind="bar")
calls['CVLEGEND'].value_counts().iplot(kind="bar")
# Out:
# <div>                            <div id="61579608-4e75-4d03-b9ef-dc437c961973" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("61579608-4e75-4d03-b9ef-dc437c961973")) {                    Plotly.newPlot(                        "61579608-4e75-4d03-b9ef-dc437c961973",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"OFFENSE","orientation":"v","text":"","x":["BURGLARY AUTO","THEFT MISD. (UNDER $950)","DISTURBANCE","THEFT FELONY (OVER $950)","VANDALISM","VEHICLE STOLEN","BURGLARY RESIDENTIAL","NARCOTICS","ASSAULT/BATTERY MISD.","ROBBERY","THEFT FROM AUTO","DOMESTIC VIOLENCE","BURGLARY COMMERCIAL","IDENTITY THEFT","FRAUD/FORGERY","ALCOHOL OFFENSE","ASSAULT/BATTERY FEL.","SEXUAL ASSAULT FEL.","GUN/WEAPON","MISSING ADULT","SEXUAL ASSAULT MISD.","THEFT FROM PERSON","BRANDISHING","VEHICLE RECOVERED","ARSON","2ND RESPONSE","KIDNAPPING","MISSING JUVENILE","DISTURBANCE - NOISE","MUNICIPAL CODE","VICE","VEHICLE CODE - DUI"],"y":[1308,809,359,336,297,256,202,198,194,184,153,137,133,118,110,109,83,47,33,30,29,28,22,15,13,9,5,4,2,2,1,1],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":1 ...
# <div>                            <div id="09924280-38ca-4bb5-bfdd-1565d25efe60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("09924280-38ca-4bb5-bfdd-1565d25efe60")) {                    Plotly.newPlot(                        "09924280-38ca-4bb5-bfdd-1565d25efe60",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"CVLEGEND","orientation":"v","text":"","x":["BURGLARY - VEHICLE","LARCENY","DISORDERLY CONDUCT","VANDALISM","ASSAULT","MOTOR VEHICLE THEFT","FRAUD","BURGLARY - RESIDENTIAL","DRUG VIOLATION","ROBBERY","LARCENY - FROM VEHICLE","FAMILY OFFENSE","BURGLARY - COMMERCIAL","LIQUOR LAW VIOLATION","SEX CRIME","WEAPONS OFFENSE","MISSING PERSON","RECOVERED VEHICLE","ARSON","NOISE VIOLATION","KIDNAPPING","ALL OTHER OFFENSES","DUI"],"y":[1308,1173,360,297,277,256,228,202,198,184,153,137,133,109,76,55,34,15,13,11,5,2,1],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automar ...
